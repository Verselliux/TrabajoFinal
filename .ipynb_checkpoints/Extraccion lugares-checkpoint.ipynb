# %%
import re
import requests 
import pandas as pd


###Lugares Turisticos de Centro america y sudamerica
consulta1 = requests.get('https://www.aarp.org/espanol/turismo/internacional/info-2016/fotos-patrimonios-culturales-america-latina.html')
consulta2 = requests.get('https://viajerocasual.com/lugares-turisticos-de-sudamerica/')

lugares1 = re.findall(r'<h2 id="listTitle.*?">(.*?)</h2>' , consulta1.text , re.DOTALL)
lugares2 = re.findall(r'<h2 class="wp-block-heading"><span class="ez-toc-section" id="[^"]*"></span>(.*?)<span class="ez-toc-section-end"></span></h2>' , 
                     consulta2.text , re.DOTALL)
Lugares = []
Paises = []

for i in lugares1:
    Lugares.append(i.split(',')[0].strip())
    Paises.append(i.split(',')[1].strip())
    
for i in lugares2:
    Lugares.append(i.split(',')[0].strip())
    Paises.append(i.split(',')[1].strip())

Datos = pd.DataFrame({'Lugares':Lugares , 'Paises':Paises})
# Out:
# Lugares    Conjunto arquitectónico de Pampulha
# Paises                                  Brasil
# Name: 0, dtype: object
# Lugares    Castillo de San Pedro de la Roca
# Paises                     Santiago de Cuba
# Name: 1, dtype: object
# Lugares    Cueva de las manos
# Paises              Argentina
# Name: 2, dtype: object
# Lugares    Tiwanaku
# Paises      Bolivia
# Name: 3, dtype: object
# Lugares    Paisaje cultural cafetero
# Paises                      Colombia
# Name: 4, dtype: object
# Lugares    Coro y su puerto
# Paises            Venezuela
# Name: 5, dtype: object
# Lugares    Ciudad de Cuzco
# Paises                Perú
# Name: 6, dtype: object
# Lugares    Parque Nacional Tikal
# Paises                 Guatemala
# Name: 7, dtype: object
# Lugares    Reserva de la Biósfera de la Mariposa Monarca
# Paises                                            México
# Name: 8, dtype: object
# Lugares    Ruinas mayas de Copán
# Paises                  Honduras
# Name: 9, dtype: object
# Lugares    Ciudad Colonial de Santo Domingo
# Paises                 República Dominicana
# Name: 10, dtype: object
# Lugares    Ciudad prehispánica y Parque Nacional de Palenque
# Paises                                                México
# Name: 11, dtype: object
# Lugares    Ciudad Portuaria de Valparaíso
# Paises                              Chile
# Name: 12, dtype: object
# Lugares    Parque Nacional Torres del Paine
# Paises                                Chile
# Name: 13, dtype: object
# Lugares    Salvador
# Paises       Brasil
# Name: 14, dtype: object
# Lugares    Columpio en el fin del mundo &#8211; Baños
# Paises                                        Ecuador
# Name: 15, dtype: object
# Lugares       Rano Raraku
# Paises     Isla de Pascua
# Name: 16, dtype: object
# Lugares    Quilotoa
# Paises      Ecuador
# Name: 17, dtype: object
# Lugares    Salar de Uyuni
# Paises            Bolivia
# Name: 18, dtype: object
# Lugares    Parque Nacional Tayrona
# Paises                    Colombia
# Name: 19, dtype: object
# Lugares    Santuario de Las Lajas
# Paises                   Colombia
# Name: 20, dtype: object
# Lugares    Glaciar Perito Moreno
# Paises                 Argentina
# Name: 21, dtype: object
# Lugares    Cementerio de la Recoleta
# Paises                  Buenos Aires
# Name: 22, dtype: object
# Lugares    Fernando de Noronha
# Paises                  Brasil
# Name: 23, dtype: object
# Lugares    Salto del Ángel
# Paises           Venezuela
# Name: 24, dtype: object
# Lugares    Isla de Chiloé
# Paises              Chile
# Name: 25, dtype: object
# Lugares    Museo de Arte Contemporáneo de Niterói
# Paises                             Río de Janeiro
# Name: 26, dtype: object
# Lugares    Machu Picchu
# Paises             Perú
# Name: 27, dtype: object
# Lugares    Los Roques
# Paises      Venezuela
# Name: 28, dtype: object
# Lugares    Valle de la Luna
# Paises                Chile
# Name: 29, dtype: object
# Lugares    Cartagena
# Paises      Colombia
# Name: 30, dtype: object
# Lugares    Cataratas Kaieteur
# Paises                 Guyana
# Name: 31, dtype: object
# Lugares    Piscina del Copacabana Palace
# Paises                    Río de Janeiro
# Name: 32, dtype: object
# Lugares    Cotopaxi
# Paises      Ecuador
# Name: 33, dtype: object
# Lugares                 Cataratas del Iguazú
# Paises     frontera entre Argentina y Brasil
# Name: 34, dtype: object
# Lugares    Parque Nacional de Lençóis Maranhenses
# Paises                                     Brasil
# Name: 35, dtype: object
# Lugares    San Pedro de Atacama
# Paises                    Chile
# Name: 36, dtype: object
# Lugares      Mendoza
# Paises     Argentina
# Name: 37, dtype: object
# Lugares    Valparaíso
# Paises          Chile
# Name: 38, dtype: object
# Lugares    Laguna Colorada
# Paises             Bolivia
# Name: 39, dtype: object
# Lugares    Jardim Botânico
# Paises      Río de Janeiro
# Name: 40, dtype: object
# Lugares    Biblioteca Española
# Paises                Medellín
# Name: 41, dtype: object
# Lugares    Cuevas de Mármol
# Paises                Chile
# Name: 42, dtype: object
# Lugares    Caño Cristales
# Paises           Colombia
# Name: 43, dtype: object
# Lugares    Islas Galápagos
# Paises             Ecuador
# Name: 44, dtype: object
# Lugares    Paraty
# Paises     Brasil
# Name: 45, dtype: object
# Lugares    Colonia del Sacramento
# Paises                    Uruguay
# Name: 46, dtype: object
# Lugares    Monte Roraima
# Paises         Venezuela
# Name: 47, dtype: object
# Lugares    Monte Monserrate
# Paises               Bogotá
# Name: 48, dtype: object
# Lugares    Canon Colca
# Paises            Perú
# Name: 49, dtype: object
# Lugares    Bariloche
# Paises     Argentina
# Name: 50, dtype: object
# Lugares    Museo de Arte Tigre
# Paises            Buenos Aires
# Name: 51, dtype: object
# Lugares    El Tatio
# Paises        Chile
# Name: 52, dtype: object
# Lugares    Monasterio de Santa Catalina
# Paises                         Arequipa
# Name: 53, dtype: object
# Lugares        Salta
# Paises     Argentina
# Name: 54, dtype: object
# Lugares    Hora Pan de Azúcar
# Paises         Río de Janeiro
# Name: 55, dtype: object
# Lugares    Lago Titicaca
# Paises              Perú
# Name: 56, dtype: object
# Lugares     La Paz
# Paises     Bolivia
# Name: 57, dtype: object
# Lugares    Cabo Polonio
# Paises          Uruguay
# Name: 58, dtype: object
# Lugares    Ostrov Navarino
# Paises               Chile
# Name: 59, dtype: object
# Lugares    Catedral de Sal
# Paises           Zipaquirá
# Name: 60, dtype: object
# Lugares      Mindo
# Paises     Ecuador
# Name: 61, dtype: object
# Lugares    Iquitos
# Paises        Perú
# Name: 62, dtype: object
